-- %%
-- Step 5 — Update Data
UPDATE employee_features_demo
SET salary = 70000
WHERE id = 2;

-- Check table

SELECT * FROM employee_features_demo;

-- Step 6 — Delete Data
DELETE FROM employee_features_demo
WHERE id = 1;

-- Step 7 — View Change Data Feed
SELECT *
FROM table_changes('employee_features_demo',0);
